# %%
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
import os
import pandas as pd

result_dir = '/home/ori/Documents/Git/relational-gcn/results/'

with open(os.path.join(result_dir, 'first_grid_with_features.csv')) as features_res_file:
    features_res = pd.read_csv(features_res_file)
with open(os.path.join(result_dir, 'first_grid_without_features.csv')) as original_res_file:
    original_res = pd.read_csv(original_res_file)

# %%
import matplotlib.pyplot as plt

# %%
features_res['test_acc'].plot()
plt.show()

# %%
features_res['test_acc'].max()
# Out:
# 0.9722222222222222

# %%
original_res['test_acc'].max()
# Out:
# 0.9722222222222222

# %%
original_res['test_acc'].plot()
plt.show()

# %%
sorted_res = features_res.sort_values('test_acc',ascending=False)
print(sorted_res.head())
# Out:
#    dataset  epochs  validation  learnrate  l2norm  hidden  bases  dropout  \
# 46    aifb      50       False       0.01   0.001      32     32      0.8
# 10    aifb      50       False       0.01   0.001       8     16      0.8
# 62    aifb      50       False       0.01   0.001      64     32      0.8
# 39    aifb      50       False       0.01   0.001      32      8      0.9
# 30    aifb      50       False       0.01   0.001      16     32      0.8
#
#     train_loss  train_acc  val_loss  val_acc  test_loss  test_acc
# 46    0.000382        1.0  0.000382      1.0   0.164173  0.972222
# 10    0.002745        1.0  0.002745      1.0   0.147047  0.972222
# 62    0.000330        1.0  0.000330      1.0   0.142816  0.972222
# 39    0.001596        1.0  0.001596      1.0   0.161187  0.972222
# 30    0.000723        1.0  0.000723      1.0   0.126189  0.972222

# %%
sorted_original = original_res.sort_values('test_acc', ascending=False)
print(sorted_original.head())
# Out:
#    dataset  epochs  validation  learnrate  l2norm  hidden  bases  dropout  \
# 23    aifb      50       False       0.01   0.001      16      8      0.9
# 2     aifb      50       False       0.01   0.001       8      4      0.8
# 3     aifb      50       False       0.01   0.001       8      4      0.9
# 20    aifb      50       False       0.01   0.001      16      8      0.2
# 43    aifb      50       False       0.01   0.001      32     16      0.9
#
#     train_loss  train_acc  val_loss   val_acc  test_loss  test_acc
# 23    0.004650   1.000000  0.004650  1.000000   0.175285  0.972222
# 2     0.011732   1.000000  0.011732  1.000000   0.184358  0.972222
# 3     0.052077   0.992857  0.052077  0.992857   0.260164  0.972222
# 20    0.003092   1.000000  0.003092  1.000000   0.180802  0.972222
# 43    0.000722   1.000000  0.000722  1.000000   0.157134  0.972222
